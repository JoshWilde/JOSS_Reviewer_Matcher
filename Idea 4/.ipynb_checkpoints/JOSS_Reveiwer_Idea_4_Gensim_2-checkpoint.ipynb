# %%
import gensim
from gensim import utils
import numpy as np
import sys
from sklearn.datasets import fetch_20newsgroups
from nltk import word_tokenize
from nltk import download
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
from JOSS_PDF_Cleaner import Clean_PDF
import re
from termcolor import colored
import warnings

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import string
import glob
from tqdm import tqdm 
#import pdfminer
from pdfminer.high_level import extract_text
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk 
nltk.download('stopwords')
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
import nltk
nltk.download('punkt')
from nltk import sent_tokenize
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sunilmcesh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sunilmcesh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sunilmcesh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('/Volumes/Seagate Backup Plus Drive/JOSS Project/GoogleNews-vectors-negative300.bin', binary=True)

# %%
PAPER_OF_INTEREST_FNAME  = glob.glob('/Volumes/Seagate Backup Plus Drive/JOSS Project/joss-papers-master/*/*/*.pdf')

# %%
K = 260
print(PAPER_OF_INTEREST_FNAME[K])
# Out:
# /Volumes/Seagate Backup Plus Drive/JOSS Project/joss-papers-master/joss-papers-master/joss.00592/10.21105.joss.00592.pdf

# %%
Paper_interest = '/Volumes/Seagate Backup Plus Drive/JOSS Project/joss-papers-master/joss-papers-master/joss.03447/10.21105.joss.03447.pdf' #PAPER_OF_INTEREST_FNAME[K]
Paper_interest = PAPER_OF_INTEREST_FNAME[K]

# %%
texts = ''
arr = []
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer
for page_layout in extract_pages(Paper_interest):
    for element in page_layout:
        if isinstance(element, LTTextContainer):
            score = Clean_PDF(element.get_text().lower())
            #print(score)
            if score == 0:
                print(colored(element.get_text().lower(), 'green'))
                arr.append(element.get_text())
                texts = texts  + element.get_text() + ' '
            else:
                print(colored(element.get_text().lower(), 'red'))
            #arr.append(element.get_text())
            #texts = texts  + element.get_text() + ' '
#arr = np.array(arr)
# Out:
# summary
#
# doi: 10.21105/joss.00592
#
# software
#
# • review
# • repository
# • archive
#
# submitted: 12 december 2017
# published: 15 june 2018
#
# license
# authors of papers retain copyright
# and release the work under a cre-
# ative commons attribution 4.0 in-
# ternational license (cc-by).
#
# aronnax: an idealised isopycnal ocean model
#
# edward w. doddridge1 and alexey radul2
#
# 1 earth, atmospheric and planetary science, massachusetts institute of technology, cambridge,
# ma, usa 2 brain and cognitive science, massachusetts institute of technology, cambridge, ma,
# usa
#
# aronnax is a highly idealised model for simulating large-scale (100-1000km) flows in the
# ocean. aronnax is intended for theoretical and empirical oceanographers, as a (relatively)
# fast and easy-to-use simulation model, bridging the gap between pencil-and-paper on one
# hand, and more faithful (and complex) computational models on the other. the numerical
# core is written in fortran to improve performance, and wrapped in python to improve
# usability.
#
# aronnax is an isopyncal model: it approximates the ocean as a number of discrete homo-
# geneous layers with spatially variable thicknesses. these layers are stacked vertically and
# the density difference between neighbouring layers is specified by the user. other widely
# used vertical coordinates require solving the equations of motion at specified vertical lev-
# els where the density is allowed to vary (s. m. griffies et al. 2000). representing the
# large-scale ocean circulation in layers contributes to aronnax’s speed: one needs only a
# few layers to achieve the same fidelity as 50 or more fixed vertical levels (stewart et al.
# 2017).
#
# aronnax serves three distinct purposes. firstly, many of the studies that use a model
# like aronnax do not provide the source code, see e.g. (davis, lique, and johnson 2014,
# février, sirven, and herbaut (2007), johnson and marshall (2002), stern (1998)). this
# increases the likelihood that coding errors go undetected, and requires that each research
# group spend time developing their own idealised model. aronnax solves these problems
# by providing an open source, tested model for the community to use. secondly, aronnax
# furthers the goals of scientific reproducibility since a simulation can be entirely specified
# with a set of input files and a version number. thirdly, aronnax provides an easy-to-use
# model that may be included in future modelling hierarchies with minimal effort, thereby
# enabling new research questions to be addressed.
#
# there are a number of other publicly available ocean models. of these the most abundant
# are general circulation models and quasigeostrophic models. general circulation models
# such as nemo, gold, mom6, and mitgcm solve a less idealised version of the navier-
# stokes equations and can be coupled with sea ice and atmospheric models to create
# fully coupled climate models. because the underlying equations are derived with fewer
# approximations these models can more faithfully simulate a wider range of flow regimes.
# however, this comes at a price; general circulation models are extremely complex, with
# numerous free parameters that must be specified, often prior to compiling the source code.
# it is possible to use most of these models in idealised configurations, but doing so requires
# a substantial investment of time from the user, and non-trivial computing resources. in
# comparison, aronnax is easy to install and cheap to run.
#
# the other abundant class of models is quasigeostrophic models. geostrophy is a balance
# between the coriolis force and the horizontal gradient of the pressure field; flows in
# which the coriolis force and the horizontal pressure gradient almost balance are known
#
# doddridge et al., (2018). aronnax: an idealised isopycnal ocean model. journal of open source software, 3(26), 592.
# https://doi.org/10.21105/joss.00592
#
# 1
#
# as quasigeostrophic. quasigeostrophic models of the ocean make use of this near balance
# and a number of other assumptions to simplify the equations of motion from a system of
# five coupled partial differential equations to a single partial differential equation (vallis
# 2006). quasigeostrophic models range in complexity from qgcm, which includes the
# option of a coupled atmosphere, to doubly periodic quasigeostrophic turbulence models
# such as pyqg and qgmodel. while quasigeostrophic models are extremely useful, there
# are some problems for which they are ill-suited. for example, the adjustment of the ocean
# circulation often occurs through ageostrophic motions such as boundary waves (johnson
# and marshall 2002), which are not represented in quasigeostrophic models. in addition,
# quasigeostrophic models are limited in their representation of sloping bathymetry (depth
# of the sea floor). for these reasons it may be preferable to use an idealised non-linear
# model such as aronnax.
#
# aronnax is mit licensed and can be retrieved from github at https://github.com/
# edoddridge/aronnax.
#
# references
#
# davis, peter e d, camille lique, and helen l. johnson. 2014. “on the link between arctic
# sea ice decline and the freshwater content of the beaufort gyre: insights from a simple
# process model.” j. clim. 27 (21):8170–84. https://doi.org/10.1175/jcli-d-14-00090.1.
#
# février, sabine, jérôme sirven, and christophe herbaut. 2007. “interaction of a coastal
# j. phys.
# kelvin wave with the mean state in the gulf stream separation area.”
# oceanogr. 37 (6):1429–44. https://doi.org/10.1175/jpo3062.1.
#
# griffies, stephen m, claus böning, frank o. bryan, eric p. chassignet, rudiger gerdes,
# hiroyasu hasumi, anthony hirst, anne-marie treguier, and david webb. 2000. “de-
# velopments in ocean climate modelling.” ocean model. 2 (2000):123–92. http://www.
# sciencedirect.com/science/article/pii/s1463500300000147.
#
# johnson, helen l., and david p. marshall.
# atlantic response to thermohaline variability.”
# http://dx.doi.org/10.1175/1520-0485(2002)032{\%}3c1121:atftsa{\%}3e2.0.co;2.
#
# “a theory for the surface
# oceanogr., 1121–32.
#
# j. phys.
#
# 2002.
#
# stern, melvin e. 1998. “separation of a density current from the bottom of a con-
# tinental slope.” j. phys. oceanogr. 28 (10):2040–9. https://doi.org/10.1175/1520-
# 0485(1998)028<2040:soadcf>2.0.co;2.
#
# stewart, k.d., a.mcc. hogg, s.m. griffies, a.p. heerdegen, m.l. ward, p. spence, and
# m.h. england. 2017. “vertical resolution of baroclinic modes in global ocean models.”
# ocean model. 113 (may). elsevier ltd:50–65. https://doi.org/10.1016/j.ocemod.2017.03.
# 012.
#
# vallis, geoffrey k. 2006. atmospheric and oceanic fluid dynamics. cambridge, uk:
# cambridge university press.
#
# doddridge et al., (2018). aronnax: an idealised isopycnal ocean model. journal of open source software, 3(26), 592.
# https://doi.org/10.21105/joss.00592
#
# 2

# %%
texts
# Out:
# 'Aronnax: An idealised isopycnal ocean model\n Aronnax is a highly idealised model for simulating large-scale (100-1000km) flows in the\nocean. Aronnax is intended for theoretical and empirical oceanographers, as a (relatively)\nfast and easy-to-use simulation model, bridging the gap between pencil-and-paper on one\nhand, and more faithful (and complex) computational models on the other. The numerical\ncore is written in Fortran to improve performance, and wrapped in Python to improve\nusability.\n Aronnax is an isopyncal model: it approximates the ocean as a number of discrete homo-\ngeneous layers with spatially variable thicknesses. These layers are stacked vertically and\nthe density difference between neighbouring layers is specified by the user. Other widely\nused vertical coordinates require solving the equations of motion at specified vertical lev-\nels where the density is allowed to vary (S. M. Griffies et al. 2000). Representing the\nlarge-scale ocean circulation in layers contributes to Aronnax’s speed: one needs only a\nfew layers to achieve the same fidelity as 50 or more fixed vertical levels (Stewart et al.\n2017).\n Aronnax serves three distinct purposes. Firstly, many of the studies that use a model\nlike Aronnax do not provide the source code, see e.g. (Davis, Lique, and Johnson 2014,\nFévrier, Sirven, and Herbaut (2007), Johnson and Marshall (2002), Stern (1998)). This\nincreases the likelihood that coding errors go undetected, and requires that each research\ngroup spend time developing their own idealised model. Aronnax solves these problems\nby providing an open source, tested model for the community to use. Secondly, Aronnax\nfurthers the goals of scientific reproducibility since a simulation can be entirely specified\nwith a set of input files and a version number. Thirdly, Aronnax provides an easy-to-use\nmodel that may be included in future modelling hierarchies with minimal effort, thereby\nenabling new research questions to be addressed.\n There are a number of other publicly available ocean models. Of these the most abundant\nare general circulation models and quasigeostrophic models. General circulation models\nsuch as NEMO, GOLD, MOM6, and MITgcm solve a less idealised version of the Navier-\nStokes equations and can be coupled with sea ice and atmospheric models to create\nfully coupled climate models. Because the underlying equations are derived with fewer\napproximations these models can more faithfully simulate a wider range of flow regimes.\nHowever, this comes at a price; general circulation models are extremely complex, with\nnumerous free parameters that must be specified, often prior to compiling the source code.\nIt is possible to use most of these models in idealised configurations, but doing so requires\na substantial investment of time from the user, and non-trivial computing resources. In\ncomparison, Aronnax is easy to install and cheap to run.\n The other abundant class of models is quasigeostrophic models. Geostrophy is a balance\nbetween the Coriolis force and the horizontal gradient of the pressure field; flows in\nwhich the Coriolis force and the horizontal pressure gradient almost balance are known\n as quasigeostrophic. Quasigeostrophic models of the ocean make use of this near balance\nand a number of other assumptions to simplify the equations of motion from a system of\nfive coupled partial differential equations to a single partial differential equation (Vallis\n2006). Quasigeostrophic models range in complexity from QGcm, which includes the\noption of a coupled atmosphere, to doubly periodic quasigeostrophic turbulence models\nsuch as PyQG and QGModel. While quasigeostrophic models are extremely useful, there\nare some problems for which they are ill-suited. For example, the adjustment of the ocean\ncirculation often occurs through ageostrophic motions such as boundary waves (Johnson\nand Marshall 2002), which are not represented in quasigeostrophic models. In addition ...

# %%
t = texts
t = t.replace('-\\n','')
t = t.replace('-\n','')
t = t.replace('\\n',' ')
t = t.replace('\n', ' ')
texts = t
print(t)
# Out:
# Aronnax: An idealised isopycnal ocean model  Aronnax is a highly idealised model for simulating large-scale (100-1000km) flows in the ocean. Aronnax is intended for theoretical and empirical oceanographers, as a (relatively) fast and easy-to-use simulation model, bridging the gap between pencil-and-paper on one hand, and more faithful (and complex) computational models on the other. The numerical core is written in Fortran to improve performance, and wrapped in Python to improve usability.  Aronnax is an isopyncal model: it approximates the ocean as a number of discrete homogeneous layers with spatially variable thicknesses. These layers are stacked vertically and the density difference between neighbouring layers is specified by the user. Other widely used vertical coordinates require solving the equations of motion at specified vertical levels where the density is allowed to vary (S. M. Griffies et al. 2000). Representing the large-scale ocean circulation in layers contributes to Aronnax’s speed: one needs only a few layers to achieve the same fidelity as 50 or more fixed vertical levels (Stewart et al. 2017).  Aronnax serves three distinct purposes. Firstly, many of the studies that use a model like Aronnax do not provide the source code, see e.g. (Davis, Lique, and Johnson 2014, Février, Sirven, and Herbaut (2007), Johnson and Marshall (2002), Stern (1998)). This increases the likelihood that coding errors go undetected, and requires that each research group spend time developing their own idealised model. Aronnax solves these problems by providing an open source, tested model for the community to use. Secondly, Aronnax furthers the goals of scientific reproducibility since a simulation can be entirely specified with a set of input files and a version number. Thirdly, Aronnax provides an easy-to-use model that may be included in future modelling hierarchies with minimal effort, thereby enabling new research questions to be addressed.  There are a number of other publicly available ocean models. Of these the most abundant are general circulation models and quasigeostrophic models. General circulation models such as NEMO, GOLD, MOM6, and MITgcm solve a less idealised version of the NavierStokes equations and can be coupled with sea ice and atmospheric models to create fully coupled climate models. Because the underlying equations are derived with fewer approximations these models can more faithfully simulate a wider range of flow regimes. However, this comes at a price; general circulation models are extremely complex, with numerous free parameters that must be specified, often prior to compiling the source code. It is possible to use most of these models in idealised configurations, but doing so requires a substantial investment of time from the user, and non-trivial computing resources. In comparison, Aronnax is easy to install and cheap to run.  The other abundant class of models is quasigeostrophic models. Geostrophy is a balance between the Coriolis force and the horizontal gradient of the pressure field; flows in which the Coriolis force and the horizontal pressure gradient almost balance are known  as quasigeostrophic. Quasigeostrophic models of the ocean make use of this near balance and a number of other assumptions to simplify the equations of motion from a system of five coupled partial differential equations to a single partial differential equation (Vallis 2006). Quasigeostrophic models range in complexity from QGcm, which includes the option of a coupled atmosphere, to doubly periodic quasigeostrophic turbulence models such as PyQG and QGModel. While quasigeostrophic models are extremely useful, there are some problems for which they are ill-suited. For example, the adjustment of the ocean circulation often occurs through ageostrophic motions such as boundary waves (Johnson and Marshall 2002), which are not represented in quasigeostrophic models. In addition, quasigeostrophic models are limited in their represe ...

# %%
download('punkt') #tokenizer, run once
download('stopwords') #stopwords dictionary, run once
stop_words = stopwords.words('english')

def preprocess(text):
    text = text.lower()
    doc = word_tokenize(text)
    doc = [word for word in doc if word not in stop_words]
    doc = [word for word in doc if word.isalpha()] #restricts string to alphabetic characters only
    return doc
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/sunilmcesh/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/sunilmcesh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
texts = [texts]
corpus = [preprocess(text) for text in texts]

# %%
corpus
# Out:
# [['aronnax',
#   'idealised',
#   'isopycnal',
#   'ocean',
#   'model',
#   'aronnax',
#   'highly',
#   'idealised',
#   'model',
#   'simulating',
#   'flows',
#   'ocean',
#   'aronnax',
#   'intended',
#   'theoretical',
#   'empirical',
#   'oceanographers',
#   'relatively',
#   'fast',
#   'simulation',
#   'model',
#   'bridging',
#   'gap',
#   'one',
#   'hand',
#   'faithful',
#   'complex',
#   'computational',
#   'models',
#   'numerical',
#   'core',
#   'written',
#   'fortran',
#   'improve',
#   'performance',
#   'wrapped',
#   'python',
#   'improve',
#   'usability',
#   'aronnax',
#   'isopyncal',
#   'model',
#   'approximates',
#   'ocean',
#   'number',
#   'discrete',
#   'homogeneous',
#   'layers',
#   'spatially',
#   'variable',
#   'thicknesses',
#   'layers',
#   'stacked',
#   'vertically',
#   'density',
#   'difference',
#   'neighbouring',
#   'layers',
#   'specified',
#   'user',
#   'widely',
#   'used',
#   'vertical',
#   'coordinates',
#   'require',
#   'solving',
#   'equations',
#   'motion',
#   'specified',
#   'vertical',
#   'levels',
#   'density',
#   'allowed',
#   'vary',
#   'griffies',
#   'et',
#   'al',
#   'representing',
#   'ocean',
#   'circulation',
#   'layers',
#   'contributes',
#   'aronnax',
#   'speed',
#   'one',
#   'needs',
#   'layers',
#   'achieve',
#   'fidelity',
#   'fixed',
#   'vertical',
#   'levels',
#   'stewart',
#   'et',
#   'al',
#   'aronnax',
#   'serves',
#   'three',
#   'distinct',
#   'purposes',
#   'firstly',
#   'many',
#   'studies',
#   'use',
#   'model',
#   'like',
#   'aronnax',
#   'provide',
#   'source',
#   'code',
#   'see',
#   'davis',
#   'lique',
#   'johnson',
#   'février',
#   'sirven',
#   'herbaut',
#   'johnson',
#   'marshall',
#   'stern',
#   'increases',
#   'likelihood',
#   'coding',
#   'errors',
#   'go',
#   'undetected',
#   'requires',
#   'research',
#   'group',
#   'spend',
#   'time',
#   'developing',
#   'idealised',
#   'model',
#   'aronnax',
#   'solves',
#   'problems',
#   'providing',
#   'open',
#   'source',
#   'tested',
#   'model',
#   'community',
#   'use',
#   'secondly',
#   'aronnax',
#   'furthers',
#   'goals',
#   'scientific',
#   'reproducibility',
#   'since',
#   'simulation',
#   'entirely',
#   'specified',
#   'set',
#   'input',
#   'files',
#   'version',
#   'number',
#   'thirdly',
#   'aronnax',
#   'provides',
#   'model',
#   'may',
#   'included',
#   'future',
#   'modelling',
#   'hierarchies',
#   'minimal',
#   'effort',
#   'thereby',
#   'enabling',
#   'new',
#   'research',
#   'questions',
#   'addressed',
#   'number',
#   'publicly',
#   'available',
#   'ocean',
#   'models',
#   'abundant',
#   'general',
#   'circulation',
#   'models',
#   'quasigeostrophic',
#   'models',
#   'general',
#   'circulation',
#   'models',
#   'nemo',
#   'gold',
#   'mitgcm',
#   'solve',
#   'less',
#   'idealised',
#   'version',
#   'navierstokes',
#   'equations',
#   'coupled',
#   'sea',
#   'ice',
#   'atmospheric',
#   'models',
#   'create',
#   'fully',
#   'coupled',
#   'climate',
#   'models',
#   'underlying',
#   'equations',
#   'derived',
#   'fewer',
#   'approximations',
#   'models',
#   'faithfully',
#   'simulate',
#   'wider',
#   'range',
#   'flow',
#   'regimes',
#   'however',
#   'comes',
#   'price',
#   'general',
#   'circulation',
#   'models',
#   'extremely',
#   'complex',
#   'numerous',
#   'free',
#   'parameters',
#   'must',
#   'specified',
#   'often',
#   'prior',
#   'compiling',
#   'source',
#   'code',
#   'possible',
#   'use',
#   'models',
#   'idealised',
#   'configurations',
#   'requires',
#   'substantial',
#   'investment',
#   'time',
#   'user',
#   'computing',
#   'resources',
#   'comparison',
#   'aronnax',
#   'easy',
#   'install',
#   'cheap',
#   'run',
#   'abundant',
#   'class',
#   'models',
#   'quasigeostrophic',
#   'models',
#   'geostrophy',
#   'balance',
#   'coriolis',
#   'force',
#   'horizontal',
#   'gradient',
#   'pressure',
#   'field',
#   'flows',
#   'coriolis',
#   'force',
#   'horizontal',
#   'pressure',
#   'gradient',
#   'almost',
#   'balance',
#   'known',
#   'quasigeostrophic',
#   'quasigeostrophic',
#   'models',
#   'ocean',
#   'make',
#   'use',
#   'near',
#   'balance',
#   'number',
#   'assumptions',
#   'simplify',
#   'equations',
#   'motion',
#   'system',
#   'five',
#   'coupled',
#   'partial',
#   'differential',
#   'equations',
#   'single',
#   'partial',
#   'differential',
#   'equation',
#   'vallis',
#   'quasigeostrophic',
#   'models',
#   'range',
#   'complexity',
#   'qgcm',
#   'includes',
#   'option',
#   'coupled',
#   'atmosphere',
#   'doubly',
#   'periodic',
#   'quasigeostrophic',
#   'turbulence',
#   'models',
#   'pyqg',
#   'qgmodel',
#   'quasigeostrophic',
#   'models',
#   'extremely',
#   'useful',
#   'problems',
#   'example',
#   'adjustment',
#   'ocean',
#   'circulation',
#   'often',
#   'occurs',
#   'ageostrophic',
#   'motions',
#   'boundary',
#   'waves',
#   'johnson',
#   'marshall',
#   'represented',
#   'quasigeostrophic',
#   'models',
#   'addition',
#   'quasigeostrophic',
#   'models',
#   'limited',
#   'representation',
#   'sloping',
#   'bathymetry',
#   'depth',
#   'sea',
#   'floor',
#   'reasons',
#   'may',
#   'preferable',
#   'use',
#   'idealised',
#   'model',
#   'aronnax',
#   'aronnax',
#   'mit',
#   'licensed',
#   'retrieved',
#   'github',
#   'https',
#   'theory',
#   'surface',
#   'phys']]

# %%
sum_vector_text = np.zeros((300))
counter = 0
for i in range(len(corpus[0])):
    if corpus[0][i] in model.vocab:
        sum_vector_text = sum_vector_text + model.wv[corpus[0][i]]
        counter = counter + 1
    else:
        print(corpus[0][i])
average_vector_text = sum_vector_text/ counter
# Out:
# aronnax
# idealised
# isopycnal
# aronnax
# idealised
# aronnax
# fortran
# aronnax
# isopyncal
# neighbouring
# griffies
# aronnax
# aronnax
# aronnax
# lique
# sirven
# herbaut
# idealised
# aronnax
# /var/folders/69/wyv1g7hn08z6pv25vg868lww0000gn/T/ipykernel_2085/2692486705.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   sum_vector_text = sum_vector_text + model.wv[corpus[0][i]]
# aronnax
# aronnax
# modelling
# quasigeostrophic
# mitgcm
# idealised
# navierstokes
# idealised
# aronnax
# quasigeostrophic
# geostrophy
# quasigeostrophic
# quasigeostrophic
# vallis
# quasigeostrophic
# qgcm
# quasigeostrophic
# pyqg
# qgmodel
# quasigeostrophic
# ageostrophic
# quasigeostrophic
# quasigeostrophic
# idealised
# aronnax
# aronnax

# %%
model.similar_by_vector(average_vector_text, topn=20)
# Out:
# [('mso_font_pitch', 0.7048326730728149),
#  ('By_Kat_Zeman', 0.693383514881134),
#  ('DIRECTORS_OF_CAPITAL_CORP.', 0.6915027499198914),
#  ('By_Elise_Viebeck', 0.6871206760406494),
#  ('By_Jonas_Elmerraji', 0.6867182850837708),
#  ('By_Laurelle_Gilbert', 0.6848405599594116),
#  ('By_Miriam_Reimer', 0.6836596131324768),
#  ('By_JANIS_CARR', 0.6830937266349792),
#  ('Horses_previewed', 0.6806297898292542),
#  ('By_Laurie_Kulikowski', 0.6799852848052979),
#  ('By_Joseph_Woelfel', 0.6780015826225281),
#  ('BY_VINCENT_MAO', 0.6707745790481567),
#  ('By_STEPHEN_WILLIS', 0.6701783537864685),
#  ('SCOTT_BAIR_Staff_Writer', 0.6695973873138428),
#  ('Nambu_theories_permeate', 0.6651671528816223),
#  ('By_Bill_Esbrook', 0.6635015606880188),
#  ('By_LEON_HALE', 0.6623695492744446),
#  ('BY_LEROY_SIGMAN', 0.6620042324066162),
#  ("JW_'S_SALOON", 0.6610624194145203),
#  ('By_Christine_Fenno', 0.6609067320823669)]

# %%
model.similar_by_vector(average_vector_text, topn=20)
# Out:
# [('DIRECTORS_OF_CAPITAL_CORP.', 0.7225965261459351),
#  ('By_Kat_Zeman', 0.7210240960121155),
#  ('mso_font_pitch', 0.7164146900177002),
#  ('By_Laurie_Kulikowski', 0.7127415537834167),
#  ('By_Elise_Viebeck', 0.7074865698814392),
#  ('By_Laurelle_Gilbert', 0.706702709197998),
#  ('By_Miriam_Reimer', 0.701018750667572),
#  ('By_Joseph_Woelfel', 0.7007259130477905),
#  ('By_STEPHEN_WILLIS', 0.6990401744842529),
#  ('BY_VINCENT_MAO', 0.6986251473426819),
#  ('By_Tejas_Gunas', 0.6981631517410278),
#  ('By_Jonas_Elmerraji', 0.6965153813362122),
#  ('By_Sara_Faiwell', 0.6912660598754883),
#  ('By_JANIS_CARR', 0.6906130313873291),
#  ('By_Bill_Esbrook', 0.690374493598938),
#  ("JW_'S_SALOON", 0.6899750232696533),
#  ('SCOTT_BAIR_Staff_Writer', 0.6890513896942139),
#  ('0_&&', 0.6884338855743408),
#  ('Horses_previewed', 0.6854375600814819),
#  ('Kiki_Von_Glinow', 0.6840978264808655)]

# %%
df_reviewers = pd.read_csv('../Data/JOSS Table Test.csv')

# %%
def GetReviewerSample_W2V(paper_vec, df_reviewers=df_reviewers):
    warnings.filterwarnings('ignore', category=DeprecationWarning)
    all_usernames = []
    all_domains = []
    all_cosine_sims = []
    for j in range(df_reviewers.shape[0]-1):
        if pd.isna(df_reviewers.iloc[j+1]['Domains/topic areas you are comfortable reviewing']) == False:
            reviewer_interests = df_reviewers.iloc[j+1]['Domains/topic areas you are comfortable reviewing'].lower()
            reviewer_interests.replace('/',' ')
            reviewer_corpus = [preprocess(reviewer_interests)]
            if bool(reviewer_corpus[0]) == True:
        #print(reviewer_corpus)
                sum_vector_text = np.zeros((300))
                counter = 0
                for i in range(len(reviewer_corpus[0])):
                    if reviewer_corpus[0][i] in model.vocab:
                        sum_vector_text = sum_vector_text + model.wv[reviewer_corpus[0][i]]
                        counter = counter + 1
                    else:
                        print(reviewer_corpus[0][i])
                if counter > 0:
                    average_Reviewer_vector_text = sum_vector_text/ counter
                    all_usernames.append(df_reviewers.username.iloc[j+1])
                    all_domains.append(reviewer_interests)
                    all_cosine_sims.append(cosine_similarity(np.array([paper_vec]), np.array([average_Reviewer_vector_text]))[0,0])
    return np.array(all_usernames), np.array(all_domains), np.array(all_cosine_sims)

# %%
from sklearn.metrics.pairwise import cosine_similarity
all_usernames, all_domains, all_cosine_sims = GetReviewerSample_W2V(average_vector_text)
# Out:
# mcmc
# visualisation
# giscience
# archaeology
# openmp
# modelling
# modelling
# euroimaging
# visualisation
# visualisation
# frequentist
# django
# microservices
# pde
# schrodinger
# knl
# sowftware
# characterisation
# nanophysics
# viszalization
# munging
# biotatistics
# fmri
# blockchain
# postestimation
# modelling
# nlp
# modelling
# sciencies
# bibliometry
# scientometry
# giscience
# munging
# datavis
# minirg
# biostats
# biofinromatics
# markov
# modelling
# biostats
# nlp
# modelling
# pcr
# chemistryphysical
# cryptocurrency
# bdi
# provers
# healthit
# behaviour
# visualisation
# astrostatistics
# analyses
# nosql
# modelling
# visualisation
# htmlwidgets
# keras
# reducation
# wcet
# analyses
# meshless
# meshfree
# bioimage
# visualisation
# optimisation
# nlp
# devsecops
# visualisation
# devops
# nlp
# sicence
# mrio
# lca
# dsmc
# visualisation
# modelling
# modelling
# visualisation
# analyses
# astrodynamics
# langevin
# jupyter
# pde
# modelling
# openmp
# markov
# archaeology
# fortran
# devops
# pdes
# pgas
# macos
# modelling
# optimisation
# algorithmics
# metabarcoding
# behavioural
# astrodynamics
# ipywidgets
# visualisation
# insar
# mle
# asdasd
# sequecning
# munging
# gamess
# delaunay
# voronoi
# modelling
# nlp
# nlp
# modelling
# geocomputation
# geosimulations
# astroparticle
# optimisation
# modelling
# scientometrics
# informetrics
# pointclouds
# mapreduce
# visualisation
# mcmc
# visualisation
# gpus
# bioinspired
# nlp
# kubernetes
# nlp
# rstats
# astroparticle
# modelling
# nbody
# cmb
# optimisation
# organisation
# modelling
# wikimedia
# mediawiki
# astrodynamics
# modelling
# fmri
# modelling
# magnetohydrodynamics
# colour
# modelling
# fluiddynamics
# modelling
# eeg
# visualisation
# modelling
# geomorph
# visualisation
# fmri
# eeg
# pupillometry
# nlp
# netowork
# goesciences
# labstraming
# lca
# visualisation
# modelling
# pdes
# melnikov
# pdes
# characterisation
# ebsd
# modelling
# convolutional
# visualisation
# tidyverse
# aeroelasticity
# optimisation
# dfghgtf
# sotware
# optimisation
# geospational
# phylogeography
# openfoam
# modelling
# nlp
# dicom
# fhir
# devops
# nlp
# estatistical
# visualisation
# modelling
# brojournal
# diffing
# bindiffing
# isomorphism
# behaviour
# rnaseq
# munging
# mklr
# modelling
# abm
# modelling
# mcmc
# mcmc
# newtonian
# nilm
# deeplearning
# segmantation
# pdes
# eeg
# ieeg
# nlp
# dataviz
# snv
# humour
# multigrid
# satisfiability
# visualisation
# archaeology
# archaeology
# visualisation
# munging
# blockchain
# modelling
# modelling
# humanties
# pupillometry
# fmm
# visualisation
# visualisation
# mcmc
# nlp
# markov
# pyrometallurgy
# thermochemistry
# visualisation
# cdisc
# modelling
# informetrics
# modelling
# milps
# mmilps
# gwas
# jupyter
# modelling
# modelling
# behavioural
# organisational
# eeg
# modelling
# abms
# nlp
# magnetohydrodynamics
# behaviour
# qcd
# boltzmann
# sience
# qma
# optimisation
# biosignals
# bioimage
# visualisation
# eigenvectors
# pdes
# modelling
# rna
# modelling
# modelling
# bioimage
# hypergeometric
# eeg
# qgis
# optimisation
# markov
# snvs
# blockchain
# phylodynamics
# analyse
# uas
# tidyverse
# visualisation
# tidyverse
# cmake
# astroparticle
# eeg
# fmri
# modelling
# datastructure
# fmri
# eeg
# eeg
# astrodynamics
# mcmc
# archaeology
# openbim
# simd
# gpgpu
# modelling
# visualisation
# pde
# linguistis
# dialectology
# modelling
# characterisation
# bibliometrix
# adverserial
# modelling
# multimodel
# tensorflow
# optimisation
# modelling
# fmri
# behavioural
# modelling
# fmri
# clinica
# neurocience
# nextflow
# tidyverse
# rlang
# mysore
# funcional
# sdr
# modelling
# visualisation
# modelling
# networkx
# astroparticle
# eeg
# nmr
# fhir
# nlp
# gggg
# devops
# rna
# vlsi
# behaviour
# cosmochemistry
# practises
# pdes
# galerkin
# wfe
# nlp
# fortran
# ansible
# archaeology
# hohai
# geocomputation
# uitilities
# flamegraphs
# modelling
# sedimentolgoical
# ndt
# metaheuristics
# mqtt
# dnssec
# modelling
# visualisation
# modelling
# modelling
# nlp
# astrodynamics
# modelling
# modelling
# mecânica
# termodinâmica
# uml
# signalling
# rnaseq
# multiomics
# astroparticle
# modelling
# modelling
# infrostructure
# parametrization
# qgis
# fmri
# sdr
# modelling
# analyses
# nlp
# distributionally
# archaeology
# kalman

# %%
def TopReviewers(number=5, all_usernames=all_usernames, all_domains=all_domains, all_cosine_sims=all_cosine_sims):
    message = 'Hello.\n I have found ' +str(number) + ' possible reviewers for this paper.'+ '\n\n'
    for J in range(number):
        index = np.argsort(all_cosine_sims)[-1-J]
        #print(index)
        ps = 'I believe '+ str(all_usernames[index]) + ' will be a good reviewer for this paper. Their domain interests and this paper have a cosine similairity score of ' + str(all_cosine_sims[index])[:6] + '. This reviewers domain interests are ' + str(all_domains[index].replace('\n', ','))
        message = message + ps + '\n\n'
    print(message)

# %%
TopReviewers()
# Out:
# Hello.
#  I have found 5 possible reviewers for this paper.
#
# I believe aaronpeikert will be a good reviewer for this paper. Their domain interests and this paper have a cosine similairity score of 0.7970. This reviewers domain interests are machine learning, - model selection, - structural equation modelling, - multimodel inference, - hierarchical data, , open science, - reproducibility, - dynamic document generation, - containers, - version control
#
# I believe wjakethompson will be a good reviewer for this paper. Their domain interests and this paper have a cosine similairity score of 0.7803. This reviewers domain interests are data management and manipulation, workflow tools, latent variable models (e.g., structural equation models, item response theory, diagnostic classification models, cognitive diagnosis models, etc.), educational assessment and psychometrics
#
# I believe fabian-s will be a good reviewer for this paper. Their domain interests and this paper have a cosine similairity score of 0.7732. This reviewers domain interests are linear models, additive models, mixed models, bayesian inference, functional data analysis, dimension reduction methods, spatial data analysis
#
# I believe peanutfun will be a good reviewer for this paper. Their domain interests and this paper have a cosine similairity score of 0.7652. This reviewers domain interests are computational physics, finite element methods, complex adaptive systems, data assimilation, ordinary & partial differential equations
#
# I believe Himscipy will be a good reviewer for this paper. Their domain interests and this paper have a cosine similairity score of 0.7609. This reviewers domain interests are high performance computing , machine learning, data science, computational fluid dynamic , energy systems, uncertainty quantification, dynamics & controls, optimization, probabilistic programming, finite element methods , renewable energy
